# %% [markdown]
# **Statistics part 2**

# %%
# ✅ 1. What is hypothesis testing in statistics?
# Hypothesis testing is a statistical method used to make decisions or inferences about population parameters using sample data.

# ✅ 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
# Null Hypothesis (H0): Assumes no effect or difference.
# Alternative Hypothesis (H1): Assumes a significant effect or difference.
# Example: H0: μ = 50, H1: μ ≠ 50

# ✅ 3. What is the significance level in hypothesis testing, and why is it important?
# The significance level (α) is the probability of rejecting the null hypothesis when it is actually true.
# Common levels: 0.05 or 5%
# It helps control the Type I error rate.

# ✅ 4. What does a P-value represent in hypothesis testing?
# The P-value indicates the probability of observing a result at least as extreme as the sample result, assuming the null hypothesis is true.

# ✅ 5. How do you interpret the P-value in hypothesis testing?
# - If P-value ≤ α: Reject H0 (result is significant)
# - If P-value > α: Fail to reject H0 (result not significant)

# ✅ 6. What are Type 1 and Type 2 errors in hypothesis testing?
# Type I Error (α): Rejecting H0 when it's true.
# Type II Error (β): Failing to reject H0 when it's false.

# ✅ 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# - One-tailed: Tests for effect in one direction (e.g., greater than)
# - Two-tailed: Tests for any difference (e.g., ≠)

# ✅ 8. What is the Z-test, and when is it used in hypothesis testing?
# A Z-test is used to test hypotheses about population means when the population variance is known and the sample size is large (n > 30).

# ✅ 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
# Z = (X̄ - μ) / (σ / √n)
# It represents how many standard errors the sample mean is from the population mean.

# ✅ 10. What is the T-distribution, and when should it be used instead of the normal distribution?
# The T-distribution is used when sample size is small (n < 30) and population standard deviation is unknown.

# ✅ 11. What is the difference between a Z-test and a T-test?
# - Z-test: Known population standard deviation, large samples.
# - T-test: Unknown population standard deviation, small samples.

# ✅ 12. What is the T-test, and how is it used in hypothesis testing?
# A T-test is used to compare sample means (one-sample, two-sample, or paired sample) when population standard deviation is unknown.

# ✅ 13. What is the relationship between Z-test and T-test in hypothesis testing?
# Both test hypotheses about means. Z-test is for known σ, T-test is for unknown σ.
# As sample size increases, T-distribution approaches normal distribution.

# ✅ 14. What is a confidence interval, and how is it used to interpret statistical results?
# A confidence interval is a range of values that likely contains the population parameter with a given confidence level (e.g., 95%).

# ✅ 15. What is the margin of error, and how does it affect the confidence interval?
# Margin of error is the amount added/subtracted from the point estimate in a confidence interval.
# Larger margin → wider interval → less precision.

# ✅ 16. How is Bayes' Theorem used in statistics, and what is its significance?
# Bayes’ Theorem calculates the probability of an event based on prior knowledge.
# P(A|B) = [P(B|A) * P(A)] / P(B)
# It is used in decision-making, machine learning, medical diagnostics, etc.

# ✅ 17. What is the Chi-square distribution, and when is it used?
# It’s a distribution used to test categorical data for independence or goodness of fit.
# It’s skewed right and only takes positive values.

# ✅ 18. What is the Chi-square goodness of fit test, and how is it applied?
# It tests if observed frequencies match expected frequencies.
# Applied by calculating:
# χ² = Σ[(O - E)² / E], where O = observed, E = expected.

# ✅ 19. What is the F-distribution, and when is it used in hypothesis testing?
# The F-distribution compares two variances.
# It’s used in ANOVA and regression analysis.

# ✅ 20. What is an ANOVA test, and what are its assumptions?
# ANOVA (Analysis of Variance) tests differences between multiple group means.
# Assumptions:
# - Normality
# - Independence
# - Equal variances (homogeneity)

# ✅ 21. What are the different types of ANOVA tests?
# - One-way ANOVA: One independent variable
# - Two-way ANOVA: Two independent variables
# - Repeated Measures ANOVA: Same subjects under different conditions

# ✅ 22. What is the F-test, and how does it relate to hypothesis testing?
# The F-test compares two population variances.
# It’s used as the test statistic in ANOVA.

# %% [markdown]
# Practical Part 1

# %%
# 📘 PW Skills - Practical Assignment (Probability, Distributions, CLT, Z-tests)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import bernoulli, binom, poisson, norm, uniform, zscore, kurtosis, skew
from scipy import stats

# ✅ 1. Generate a random variable and display its value
rv = np.random.randint(1, 100)
print("Random Variable:", rv)

# ✅ 2. Discrete uniform distribution PMF
x = np.arange(1, 7)
pmf = [1/6] * 6
plt.stem(x, pmf)
plt.title("Discrete Uniform Distribution (PMF)")
plt.xlabel("Outcomes")
plt.ylabel("Probability")
plt.show()

# ✅ 3. Bernoulli PDF Function
def bernoulli_pdf(p, x):
    return p if x == 1 else (1 - p)
print("Bernoulli PDF (p=0.6, x=1):", bernoulli_pdf(0.6, 1))

# ✅ 4. Simulate Binomial (n=10, p=0.5) and plot
binom_data = binom.rvs(n=10, p=0.5, size=1000)
plt.hist(binom_data, bins=11, color='skyblue', edgecolor='black')
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.show()

# ✅ 5. Create & Visualize Poisson Distribution
poisson_data = poisson.rvs(mu=3, size=1000)
sns.histplot(poisson_data, bins=15, kde=False)
plt.title("Poisson Distribution (mu=3)")
plt.show()

# ✅ 6. CDF of Discrete Uniform Distribution
x = np.arange(1, 7)
cdf = np.cumsum([1/6]*6)
plt.step(x, cdf, where='post')
plt.title("CDF of Discrete Uniform Distribution")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# ✅ 7. Continuous Uniform Distribution Visualization
uniform_data = uniform.rvs(loc=0, scale=10, size=1000)
sns.histplot(uniform_data, bins=20, kde=True)
plt.title("Continuous Uniform Distribution")
plt.show()

# ✅ 8. Simulate normal distribution & plot histogram
norm_data = np.random.normal(loc=50, scale=10, size=1000)
sns.histplot(norm_data, bins=30, kde=True)
plt.title("Normal Distribution Histogram")
plt.show()

# ✅ 9. Z-scores from dataset & plot
z_scores = zscore(norm_data)
plt.plot(z_scores)
plt.title("Z-Scores of Normal Data")
plt.grid(True)
plt.show()

# ✅ 10. CLT with non-normal distribution
samples = [np.mean(np.random.exponential(scale=2, size=30)) for _ in range(1000)]
sns.histplot(samples, bins=30, kde=True)
plt.title("CLT Simulation with Exponential Distribution")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# ✅ 11. Simulate multiple samples from normal distribution (CLT)
sample_means = [np.mean(np.random.normal(loc=50, scale=10, size=40)) for _ in range(1000)]
sns.histplot(sample_means, kde=True)
plt.title("CLT Verification with Normal Samples")
plt.show()

# ✅ 12. Standard Normal Distribution (PDF)
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)
plt.plot(x, y)
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.grid(True)
plt.show()

# ✅ 13. Binomial probabilities for given trials
n, p = 10, 0.5
x = np.arange(0, 11)
probs = binom.pmf(x, n, p)
plt.bar(x, probs)
plt.title("Binomial Probabilities (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.show()

# ✅ 14. Z-score comparison
data_point = 60
mean = 50
std_dev = 10
z = (data_point - mean) / std_dev
print("Z-score for data point 60:", z)
print("Probability from standard normal dist:", norm.cdf(z))

# ✅ 15. Hypothesis Testing using Z-statistics
sample = np.random.normal(52, 5, 50)
pop_mean = 50
z_stat, p_val = stats.ttest_1samp(sample, pop_mean)
print("Z-statistic:", z_stat)
print("P-value:", p_val)

# ✅ 16. Confidence Interval from dataset
mean = np.mean(sample)
std_err = stats.sem(sample)
ci = stats.t.interval(confidence=0.95, df=len(sample)-1, loc=mean, scale=std_err)
print("95% Confidence Interval:", ci)

# ✅ 17. Confidence Interval of Normal Sample Mean
norm_sample = np.random.normal(loc=100, scale=15, size=30)
mean = np.mean(norm_sample)
ci = stats.t.interval(0.95, df=29, loc=mean, scale=stats.sem(norm_sample))
print("CI for Mean (Normal Sample):", ci)

# ✅ 18. PDF of Normal Distribution
x = np.linspace(70, 130, 200)
y = norm.pdf(x, loc=100, scale=15)
plt.plot(x, y)
plt.title("PDF of Normal Distribution (μ=100, σ=15)")
plt.grid(True)
plt.show()

# ✅ 19. CDF of Poisson Distribution
x = np.arange(0, 15)
cdf_vals = poisson.cdf(x, mu=4)
plt.step(x, cdf_vals, where='post')
plt.title("CDF of Poisson Distribution (μ=4)")
plt.grid(True)
plt.show()

# ✅ 20. Continuous Uniform Random Variable & Expected Value
uniform_data = np.random.uniform(0, 10, 1000)
expected_value = np.mean(uniform_data)
print("Expected Value (Uniform 0-10):", expected_value)

# ✅ 21. Compare Standard Deviations & Visualize
a = np.random.normal(50, 5, 100)
b = np.random.normal(50, 15, 100)
print("Std Dev A:", np.std(a))
print("Std Dev B:", np.std(b))
sns.histplot(a, color='blue', label='A', kde=True)
sns.histplot(b, color='red', label='B', kde=True)
plt.legend()
plt.title("Standard Deviation Comparison")
plt.show()

# ✅ 22. Range & IQR of Normal Distribution
data = np.random.normal(100, 20, 1000)
range_val = np.ptp(data)
iqr_val = stats.iqr(data)
print("Range:", range_val)
print("IQR:", iqr_val)

# ✅ 23. Z-score Normalization & Visualize
z_norm = zscore(data)
sns.histplot(z_norm, bins=30, kde=True)
plt.title("Z-score Normalized Data")
plt.show()

# ✅ 24. Skewness & Kurtosis of Normal Distribution
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Random Variable: 92
# Bernoulli PDF (p=0.6, x=1): 0.6
# Z-score for data point 60: 1.0
# Probability from standard normal dist: 0.8413447460685429
# Z-statistic: 3.6910248385333375
# P-value: 0.0005609479396455378
# 95% Confidence Interval: (np.float64(51.49830002138426), np.float64(55.07967007047727))
# CI for Mean (Normal Sample): (np.float64(89.4985644732013), np.float64(99.97744631501598))
# Expected Value (Uniform 0-10): 5.120309682745654
# Std Dev A: 5.5834297079847595
# Std Dev B: 13.195611197615197
# Range: 133.61938671478464
# IQR: 26.601207264560756
# Skewness: 0.04859445376540636
# Kurtosis: 0.015232442770234389

# %% [markdown]
# Practical Part 2

# %%
# 📘 PW Skills - Practical Hypothesis Testing with Python

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ✅ 1. Z-test: Compare sample mean to known population mean
def z_test(sample, pop_mean, pop_std):
    sample_mean = np.mean(sample)
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(len(sample)))
    p_value = 2 * (1 - stats.norm.cdf(abs(z)))
    print(f"Z-statistic: {z:.4f}, P-value: {p_value:.4f}")
sample = np.random.normal(52, 10, 50)
z_test(sample, 50, 10)

# ✅ 2. Simulate data and perform hypothesis testing with P-value
data = np.random.normal(100, 15, 30)
t_stat, p_val = stats.ttest_1samp(data, 95)
print("One-sample T-test:", "T-statistic =", t_stat, "P-value =", p_val)

# ✅ 3. One-sample Z-test
def one_sample_ztest(sample, pop_mean, pop_std):
    z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
    p = 2 * (1 - stats.norm.cdf(abs(z)))
    print("Z =", z, "P =", p)
one_sample_ztest(np.random.normal(48, 10, 40), 50, 10)

# ✅ 4. Two-tailed Z-test with decision region visualization
sample = np.random.normal(52, 10, 30)
z_stat = (np.mean(sample) - 50) / (10 / np.sqrt(len(sample)))
alpha = 0.05
z_crit = stats.norm.ppf(1 - alpha/2)

x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)
plt.plot(x, y, label='Standard Normal')
plt.axvline(z_crit, color='red', linestyle='--', label='Critical Value')
plt.axvline(-z_crit, color='red', linestyle='--')
plt.axvline(z_stat, color='blue', linestyle='-', label='Z-statistic')
plt.legend()
plt.title("Two-tailed Z-test Decision Region")
plt.grid(True)
plt.show()

# ✅ 5. Visualize Type 1 and Type 2 Errors
def visualize_errors(mu0=50, mu1=52, sigma=10, n=30, alpha=0.05):
    x = np.linspace(40, 60, 1000)
    z_crit = stats.norm.ppf(1 - alpha)
    threshold = mu0 + z_crit * (sigma / np.sqrt(n))
    y0 = stats.norm.pdf(x, mu0, sigma / np.sqrt(n))
    y1 = stats.norm.pdf(x, mu1, sigma / np.sqrt(n))

    plt.plot(x, y0, label="H0: μ=50", color='blue')
    plt.plot(x, y1, label="H1: μ=52", color='green')
    plt.axvline(threshold, color='red', linestyle='--', label="Critical Value")
    plt.fill_between(x, y0, where=(x > threshold), color='red', alpha=0.3, label="Type I Error")
    plt.fill_between(x, y1, where=(x < threshold), color='orange', alpha=0.3, label="Type II Error")
    plt.legend()
    plt.title("Type I and Type II Errors")
    plt.grid(True)
    plt.show()
visualize_errors()

# ✅ 6. Independent T-test
group1 = np.random.normal(55, 5, 30)
group2 = np.random.normal(60, 5, 30)
t_stat, p_val = stats.ttest_ind(group1, group2)
print("Independent T-test:\nT-stat =", t_stat, "P-value =", p_val)

# ✅ 7. Paired Sample T-test & Visualization
before = np.random.normal(50, 5, 20)
after = before + np.random.normal(1.5, 2, 20)
t_stat, p_val = stats.ttest_rel(before, after)
print("Paired T-test:\nT-stat =", t_stat, "P-value =", p_val)
plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.title("Before vs After Comparison")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 8. Compare Z-test and T-test
sample = np.random.normal(100, 15, 30)
pop_mean = 95
z = (np.mean(sample) - pop_mean) / (15 / np.sqrt(len(sample)))
t_stat, p_val = stats.ttest_1samp(sample, pop_mean)
print("Z-test:", z, "\nT-test:", t_stat)

# ✅ 9. Confidence Interval Function
def confidence_interval(sample, confidence=0.95):
    mean = np.mean(sample)
    se = stats.sem(sample)
    margin = stats.t.ppf((1 + confidence)/2, df=len(sample)-1) * se
    ci = (mean - margin, mean + margin)
    print(f"{int(confidence*100)}% Confidence Interval: {ci}")
confidence_interval(np.random.normal(50, 5, 40))

# ✅ 10. Margin of Error Calculator
def margin_of_error(sample, confidence=0.95):
    se = stats.sem(sample)
    critical = stats.t.ppf((1 + confidence)/2, df=len(sample)-1)
    return critical * se
sample = np.random.normal(50, 5, 30)
print("Margin of Error:", margin_of_error(sample))

# ✅ 11. Bayesian Inference with Bayes' Theorem
# P(A|B) = (P(B|A) * P(A)) / P(B)
def bayes_theorem(p_a, p_b_given_a, p_b_given_not_a):
    p_not_a = 1 - p_a
    p_b = p_b_given_a * p_a + p_b_given_not_a * p_not_a
    return (p_b_given_a * p_a) / p_b
result = bayes_theorem(0.01, 0.99, 0.05)
print("Bayesian Inference Result (P(A|B)):", result)

# ✅ 12. Chi-square test for independence
data = pd.DataFrame({'Gender': ['M', 'M', 'F', 'F'], 'Preference': ['Yes', 'No', 'Yes', 'No'], 'Count': [20, 10, 30, 40]})
contingency = data.pivot(index='Gender', columns='Preference', values='Count')
chi2, p, dof, expected = stats.chi2_contingency(contingency)
print("Chi-Square Test:\nChi2 =", chi2, "P =", p)

# ✅ 13. Calculate Expected Frequencies
print("Expected Frequencies:\n", expected)

# ✅ 14. Goodness-of-fit test
observed = [30, 50, 20]
expected = [33.33, 33.33, 33.33]

# Scale expected to match sum of observed exactly
expected = np.array(expected)
expected = expected * (np.sum(observed) / np.sum(expected))

chi2, p = stats.chisquare(f_obs=observed, f_exp=expected)
print("Goodness-of-Fit Test:\nChi2 =", chi2, "P-value =", p)
# Out:
# Z-statistic: 1.8288, P-value: 0.0674
# One-sample T-test: T-statistic = 2.2533647671546366 P-value = 0.03196912990392775
# Z = 1.1161204981038668 P = 0.264370559071617
# Independent T-test:
# T-stat = -4.98688133101006 P-value = 5.891595515282057e-06
# Paired T-test:
# T-stat = -3.6992806159059177 P-value = 0.0015222381883938268
# Z-test: 0.14570469149195
# T-test: 0.13785920269962573
# 95% Confidence Interval: (np.float64(48.617427419355295), np.float64(51.723088170902685))
# Margin of Error: 2.444795036232291
# Bayesian Inference Result (P(A|B)): 0.16666666666666669
# Chi-Square Test:
# Chi2 = 3.857142857142857 P = 0.04953461343562649
# Expected Frequencies:
#  [[35. 35.]
#  [15. 15.]]
# Goodness-of-Fit Test:
# Chi2 = 14.0 P-value = 0.0009118819655545164
